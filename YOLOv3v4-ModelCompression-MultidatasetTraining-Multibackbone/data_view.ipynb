# %%
import json

from torch.utils.data import DataLoader

from models import *
from utils.datasets import *
from utils.utils import *

import torch
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
path = 'data/coco2017/val2017.txt'
imgsz = 416
batch_size = 4
rect = True
single_cls= False

# %%
dataset = LoadImagesAndLabels(path, imgsz, batch_size, rect=False, single_cls=single_cls)
dataloader = DataLoader(dataset,
                                batch_size=batch_size,
                                num_workers=0,
                                pin_memory=True,
                                collate_fn=dataset.collate_fn)
# Out:
# Caching labels (4952 found, 48 missing, 0 empty, 0 duplicate, for 5000 images): 100%|██████████| 5000/5000 [00:00<00:00, 11632.03it/s]

# %%
idx = 0
img = dataset[idx][0]
img = np.array(img.permute(1, 2, 0))
print(img.shape)
plt.imshow(img)
plt.show()
# Out:
# (416, 416, 3)

# %%
dataset = LoadImagesAndLabels(path, imgsz, batch_size, rect=True, single_cls=single_cls)
dataloader = DataLoader(dataset,
                                batch_size=batch_size,
                                num_workers=0,
                                pin_memory=True,
                                collate_fn=dataset.collate_fn)
# Out:
# Caching labels (4952 found, 48 missing, 0 empty, 0 duplicate, for 5000 images): 100%|██████████| 5000/5000 [00:00<00:00, 11733.75it/s]

# %%
idx = 0
img = dataset[idx][0]
img = np.array(img.permute(1, 2, 0))
print(img.shape)
plt.imshow(img)
plt.show()
# Out:
# (128, 416, 3)
